# %% [markdown]
# # Assignment 1 - Probability, Linear Algebra, Programming, and Git
#
# ## *Yujing Ke*
# Netid:  *yk175*

# %% [markdown]
# # Probability and Statistics Theory

# %% [markdown]
# ## 1
# Let $f(x) = \begin{cases}
#                 0           & x < 0  \\
#                 \alpha x^2  & 0 \leq x \leq 2 \\
#                 0           & 2 < x
#             \end{cases}$
#
# For what value of $\alpha$ is $f(x)$ a valid probability density function?
#
# *Note: for all assignments, write out all equations and math for all assignments using markdown and [LaTeX](https://tobi.oetiker.ch/lshort/lshort.pdf) and show all work*

# %% [markdown]
# **ANSWER**
#
# According to the definition of probability density function, the area under the curve f(x) is 1. By observing the function, we have
# $$\int_{0}^{2} ax^2 dx = 1$$
# By calculate the integral, we know that $\int_{0}^{2} \alpha x^2 dx = \frac{1}{3}\alpha x^3$ valued from 0 to 2. We plug in the end points and get $\frac{1}{3}\alpha 2^3 - 0 = 1$. Therefore, we can know that the value of $\alpha $ is $\frac{3}{8}$.

# %% [markdown]
# ## 2
# What is the cumulative distribution function (CDF) that corresponds to the following probability distribution function? Please state the value of the CDF for all possible values of $x$.
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$

# %% [markdown]
# **ANSWER**
#
# CDF is defined as $F_X(x) = P(X \leq x)$, and the PDF is given that it is constant between 0 and 3 and is 0 otherwise. Therefore we can see that $F_X(x) = \int_{-\infty}^{x}p(t)dt = \int_{-\infty}^{x}\frac{1}{3}dt = \frac{1}{3}x$ between $\infty$ and 3.
#
# Therefore, the CDF is:
# $F(x) = \begin{cases}
#     0           & x < 0 \\
#     \frac{1}{3}x & 0 < x < 3 \\
#     1           & x \geq 3
#     \end{cases}$

# %% [markdown]
# ## 3
# For the probability distribution function for the random variable $X$,
#
# $f(x) = \begin{cases}
#     \frac{1}{3} & 0 < x < 3 \\
#     0           & \text{otherwise}
#     \end{cases}$
#
# what is the (a) expected value and (b) variance of $X$. *Show all work*.

# %% [markdown]
# **ANSWER**
#
# (a) Expected value:
#
# The mean of a distribution given by distribution function f(x) is defined as
# $$\int_{-\infty}^{\infty}xf(x)dx \\
# = \int_{0}^{3}\frac{1}{3}x dx + \int_{-\infty}^{\infty} 0 dx \\
# = \frac{1}{6}x^2\Big|_0^3
# = \frac{3}{2}$$.
#
# (b) Variance:
#
# The variance of a distribution given by distribution function f(x) is defined as
# $$\int_{-\infty}^{\infty}(x-\mu)^2f(x)dx \\
# = \int_{0}^{3}\frac{1}{3}(x -\frac{3}{2})^2dx \\
# = \int_{0}^{3} \frac{1}{3} x^2 - x + \frac{3}{4} dx \\
# = \int_{0}^{3} \frac{1}{3} x^2 dx - \int_{0}^{3}x dx + \int_{0}^{3} \frac{3}{4} dx\\
# = \frac{1}{9}x^3\Big|_0^3 - \frac{1}{2}x^2\Big|_0^3 + \frac{3}{4}x\Big|_0^3\\
# = 3 - 9/2 + 9/4 = 3/4
# $$.

# %% [markdown]
# ## 4
# Consider the following table of data that provides the values of a discrete data vector $\mathbf{x}$ of samples from the random variable $X$, where each entry in $\mathbf{x}$ is given as $x_i$.
#
# *Table 1. Dataset N=5 observations*
#
# |        | $x_0$ | $x_1$ | $x_2$ | $x_3$ | $x_4$ |
# |------  |-------|-------|-------|-------|-------|
# |$\textbf{x}$| 2     | 3     | 10    | -1    | -1    |
#
# What is the (a) mean, (b) variance, and the  of the data?
#
# *Show all work. Your answer should include the definition of mean, median, and variance in the context of discrete data.*

# %% [markdown]
# **ANSWER**
#
# (a) Mean
# The mean is defined as the sum of the data divided by the size of data, also known as the average.
#
# $Mean = (x_1 + x_2 + ... + x_i)/i \\
# = (2 + 3 + 10 - 1 - 1) / 5 \\
# = \frac{13}{5} = 2.6$
#
# (b) Variance
#
# The population variance is defined as the sum of squared difference between mean and each discrete data divided by degrees of freedom.
#
# $Var = \frac{1}{4}((2 - 2.6)^2 + (3 - 2.6)^2 + (10 - 2.6)^2 + (-1 - 2.6)^2 + (-1 - 2.6)^2)\\
# = \frac{1}{4}(0.36 + 0.16 + 54.76 + 12.96*2)\\
# =20.3
# $
#
# (c) Median
#
# The median is defined as the middle valur of $x_i$. In this data set the median is 2, as there are two data points smaller than it and two data points greater than it.

# %% [markdown]
# ## 5
# Review of counting from probability theory.
#
# (a) How many different 7-place licence plates are possible if the first 3 places only contain letters and te last 4 only contain numbers?
#
# (b) How many different batting orders are possible for a baseball team with 9 players?
#
# (c) How many batting orders of 5 players are possible for a team with 9 players total?
#
# (d) Let's assume this class has 26 students and we want to form project teams. How many unique teams of 3 are possible?
#
# *Hint: For each problem, determine if order matters, and if it should be calculated with or without replacement.*

# %% [markdown]
# **ANSWER**
#
# (a)
#
# For a, the order matters and it should be calculated with replacement. For the letters part there are $26*26*26$ outcomes, for the number part has $10^4$ outcomes. Together there are
# $
# 26^3 * 10^4 = 175760000
# $ different 7 place licence plates.
#
# (b)
# For b, the order matters should be calculated without replacement. When we choose the first player, we have 9 choices. When we comes to the second, we have 8 choices... Therefore, in total there are $9*8*7*...*2*1 = 9! = 362880$ different batting orders.
#
# (c)
# For c, the order matters should be calculated without replacement. We choose 5 out of 9, and do a permutation for 5 players. Therefore, there are ${9\choose 5} * P_{5}^{5} = 9*8*7*6*5= 15120$ batting orders.
#
#
# (d)
# for d, the order does not matter and it should be calculated without replacement. we choose 3 out of 26, therefore there are ${26 \choose 3} = 26*25*24/(1*2*3) = 2600$ unique teams of 3 are possible.

# %% [markdown]
# # Linear Algebra

# %% [markdown]
# ## 6
# **Matrix manipulations and multiplication**. Machine learning involves working with many matrices, so this exercise will provide you with the opportunity to practice those skills.
#
# Let
# $\mathbf{A} =  \begin{bmatrix}
# 1 & 2 & 3 \\
# 2 & 4 & 5 \\
# 3 & 5 & 6
# \end{bmatrix}$, $\mathbf{b} =  \begin{bmatrix}
# -1  \\
# 3  \\
# 8
# \end{bmatrix}$, $\mathbf{c} =  \begin{bmatrix}
# 4  \\
# -3  \\
# 6
# \end{bmatrix}$, and $\mathbf{I} =  \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{bmatrix}$
#
# Compute the following or indicate that it cannot be computed:
#
# 1. $\mathbf{A}\mathbf{A}$
# 2. $\mathbf{A}\mathbf{A}^T$
# 3. $\mathbf{A}\mathbf{b}$
# 4. $\mathbf{A}\mathbf{b}^T$
# 5. $\mathbf{b}\mathbf{A}$
# 6. $\mathbf{b}^T\mathbf{A}$
# 7. $\mathbf{b}\mathbf{b}$
# 8. $\mathbf{b}^T\mathbf{b}$
# 9. $\mathbf{b}\mathbf{b}^T$
# 10. $\mathbf{b} + \mathbf{c}^T$
# 11. $\mathbf{b}^T\mathbf{b}^T$
# 12. $\mathbf{A}^{-1}\mathbf{b}$
# 13. $\mathbf{A}\circ\mathbf{A}$
# 14. $\mathbf{b}\circ\mathbf{c}$
#
# *Note: The element-wise (or Hadamard) product is the product of each element in one matrix with the corresponding element in another matrix, and is represented by the symbol "$\circ$".*

# %% [markdown]
# **ANSWER**

# %%
A = np.array([[1, 2, 3], [2, 4, 5], [3, 5, 6]])
b = np.array([[-1], [3], [8]])
c = np.array([[4], [-3], [6]])
q1 =  np.matmul(A, A)
print("1.)")
print(q1)

At = A.transpose()
q2 = np.matmul(A, At)
print("2.)")
print(q2)

q3 = np.matmul(A, b)
print("3.)")
print(q3)

#bt = b.transpose()
#q4 = np.matmul(A, bt)
print("4.) cannot be computed")
#print(q4)

#q5 = np.matmul(b,A)
print("5.) cannot be computed")

q6 = np.matmul(bt,A)
print("6.)")
print(q6)

#q7 = np.matmul(b,b)
print("7.) cannot be computed")

q8 = np.matmul(bt,b)
print("8.)")
print(q8)

q9 = np.matmul(b,bt)
print("9.)")
print(q9)

ct = c.transpose()
#q10 = np.add(b + ct)
print("10.) cannot be computed")

#q11 = np.matmul(bt,bt)
print("11.) cannot be computed")

from numpy.linalg import inv
Ainv = inv(A)
q12 = np.matmul(Ainv,b)
print("12.)")
print(q12)

q13 = np.multiply(A,A)
print("13.)")
print(q13)

q14 = np.multiply(b,c)
print("14.)")
print(q14)
# Out:
# 1.)
# [[14 25 31]
#  [25 45 56]
#  [31 56 70]]
# 2.)
# [[14 25 31]
#  [25 45 56]
#  [31 56 70]]
# 3.)
# [[29]
#  [50]
#  [60]]
# 4.) cannot be computed
# 5.) cannot be computed
# 6.)
# [[29 50 60]]
# 7.) cannot be computed
# 8.)
# [[74]]
# 9.)
# [[ 1 -3 -8]
#  [-3  9 24]
#  [-8 24 64]]
# 10.) cannot be computed
# 11.) cannot be computed
# 12.)
# [[ 6.]
#  [ 4.]
#  [-5.]]
# 13.)
# [[ 1  4  9]
#  [ 4 16 25]
#  [ 9 25 36]]
# 14.)
# [[-4]
#  [-9]
#  [48]]

# %% [markdown]
# ## 6
# **Eigenvectors and eigenvalues**. Eigenvectors and eigenvalues are useful for some machine learning algorithms, but the concepts take time to solidly grasp. For an intuitive review of these concepts, explore this [interactive website at Setosa.io](http://setosa.io/ev/eigenvectors-and-eigenvalues/). Also, the series of linear algebra videos by Grant Sanderson of 3Brown1Blue are excellent and can be viewed on youtube [here](https://www.youtube.com/playlist?list=PLZHQObOWTQDPD3MizzM2xVFitgF8hE_ab).
#
# 1. Calculate the eigenvalues and corresponding eigenvectors of matrix $\mathbf{A}$ above, from the last question.
# 2. Choose one of the eigenvector/eigenvalue pairs, $\mathbf{v}$ and $\lambda$, and show that $\mathbf{A} \mathbf{v} = \lambda \mathbf{v}$. Also show that this relationship extends to higher orders: $\mathbf{A} \mathbf{A} \mathbf{v} = \lambda^2 \mathbf{v}$
# 3. Show that the eigenvectors are orthogonal to one another (e.g. their inner product is zero). This is true for real, symmetric matrices.

# %% [markdown]
# **ANSWER**

# %%
from numpy import linalg as LA
w, v = LA.eig(A)
v = np.array([-0.3279, -0.5910,  -0.7369])
v1 = v1.transpose()
v2 = np.array([-0.73697623, -0.32798528, 0.59100905])
v3 = np.array([0.59100905, -0.73697623, 0.32798528])
print("1.)")
print("The eigen values are",w,".")
print("The transposed eigen vectors are",v1,v2,v3,'.')

print("2.)")


Av = np.matmul(A,v1)
print("Av = ",Av)
lambdav = 11.3448*v1
print("λv = ",lambdav)
print("Here we can see that Av=λv.")

AAV = np.matmul(A,Av)
print("AAv = ",AAV)
lambdalambdav = 11.3448*lambdav
print("λ^2v = ",lambdalambdav)
print("From here we can see that AAv=λ^2v.")

print("3.)")

print("The three pairs of dot products are: ")
tmp1 = np.dot(v,v2)
print("Eig Vector 1 dot Eig vector 2: ",tmp1)
tmp2 = np.dot(v,v3)
print("Eig Vector 1 dot Eig vector 3: ",tmp2)
tmp3 = np.dot(v2,v3)
print("Eig Vector 2 dot Eig vector 3: ",tmp3)
print("As we can see that these are all small values very close to zero.")
print("Therefore, the eigenvectors are orthogonal to one another.")
# Out:
# 1.)
# The eigen values are [ 11.34481428  -0.51572947   0.17091519] .
# The transposed eigen vectors are [-0.3279 -0.591  -0.7369] [-0.73697623 -0.32798528  0.59100905] [ 0.59100905 -0.73697623  0.32798528] .
# 2.)
# Av =  [-3.7206 -6.7043 -8.3601]
# λv =  [-3.71995992 -6.7047768  -8.35998312]
# Here we can see that Av=λv.
# AAv =  [-42.2095 -76.0589 -94.8439]
# λ^2v =  [-42.2022013  -76.06435184 -94.8423365 ]
# From here we can see that AAv=λ^2v.
# 3.)
# The three pairs of dot products are:
# Eig Vector 1 dot Eig vector 2:  -2.07626480001e-05
# Eig Vector 1 dot Eig vector 3:  6.8731603e-05
# Eig Vector 2 dot Eig vector 3:  2.33179686671e-09
# As we can see that these are all small values very close to zero.
# Therefore, the eigenvectors are orthogonal to one another.

# %% [markdown]
# # Numerical Programming

# %% [markdown]
# ## 7
# Speed comparison between vectorized and non-vectorized code. Begin by creating an array of 10 million random numbers using the numpy random.randn module. Compute the sum of the squares first in a for loop, then using Numpy's `dot` module. Time how long it takes to compute each and report the results and report the output. How many times faster is the vectorized code than the for loop approach?
#
# *Note: all code should be well commented, properly formatted, and your answers should be output using the `print()` function as follows (where the # represents your answers, to a reasonable precision):
#
# `Time [sec] (non-vectorized): ######`
#
# `Time [sec] (vectorized):     ######`
#
# `The vectorized code is ##### times faster than the vectorized code`

# %% [markdown]
# **ANSWER**

# %%
import numpy as np
import time

# Generate the random samples
x_list = np.random.randn(10000000)
print(x_list)
# Out:
# [-0.4842852  -0.96046752 -0.54263523 ...,  0.28329242 -1.1717637
#   0.29975476]

# %%
x_list = np.random.randn(10)
print(x_list)
# Out:
# [ 1.17958175  1.77374749  0.27014378  0.10683891  1.11306779 -0.01172395
#  -0.83955297 -0.20891471  0.69581926 -1.80219071]

# %%
# %%timeit -n 1 -r 1
sum = 0
for x in x_list:
    sum = sum + x**2
#print(sum)
# Compute the sum of squares the non-vectorized way (using a for loop)
# Out:
# 57.6 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -n 1 -r 1
sum_v = 0
sum_v = np.dot(x_list,x_list)
#print(sum_v)
# Compute the sum of squares the vectorized way (using numpy)
# Out:
# 28.3 µs ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
print("Time [sec] (non-vectorized): {}".format(0.00000576))
print("Time [sec] (vectorized): {}".format(0.00000283))
tmp = 576/283
print("The vectorized code is {} times faster than the non-vectorized code.".format(tmp))
# Print the results
# Out:
# Time [sec] (non-vectorized): 5.76e-06
# Time [sec] (vectorized): 2.83e-06
# The vectorized code is 2.035335689045936 times faster than the non-vectorized code.

# %% [markdown]
# ## 8
# One popular Agile development framework is Scrum (a paradigm recommended for data science projects). It emphasizes the continual evolution of code for projects, becoming progressively better, but starting with a quickly developed minimum viable product. This often means that code written early on is not optimized, and that's a good thing - it's best to get it to work first before optimizing. Imagine that you wrote the following code during a sprint towards getting an end-to-end system working. Vectorize the following code and show the difference in speed between the current implementation and a vectorized version.
#
# The function below computes the function $f(x,y) = x^2 - 2 y^2$ and determines whether this quantity is above or below a given threshold, `thresh=0`. This is done for $x,y \in \{-4,4\}$, over a 2,000-by-2,000 grid covering that domain.
#
# (a) Vectorize this code and demonstrate (as in the last exercise) the speed increase through vectorization and (b) plot the resulting data - both the function $f(x,y)$ and the thresholded output - using [`imshow`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.imshow.html?highlight=matplotlib%20pyplot%20imshow#matplotlib.pyplot.imshow) from `matplotlib`.
#
# *Hint: look at the `numpy` [`meshgrid`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.meshgrid.html) documentation*

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# Initialize variables for this exerise
x = np.arange(-4,4,0.004)
y = np.arange(-4,4,0.004)
xx,yy = np.meshgrid(x, y, sparse=True)

# %%
# %%timeit -n 1 -r 1
fxy = []
for i in range(2000):
    for j in range(2000):
        fxy.append(x[i]**2 - 2*y[j]**2)
result = np.reshape(fxy, (2000, 2000))
print(result)
# Nonvectorized implementation
# Out:
# [[-16.       -15.936032 -15.872128 ..., -15.808288 -15.872128 -15.936032]
#  [-16.031984 -15.968016 -15.904112 ..., -15.840272 -15.904112 -15.968016]
#  [-16.063936 -15.999968 -15.936064 ..., -15.872224 -15.936064 -15.999968]
#  ...,
#  [-16.095856 -16.031888 -15.967984 ..., -15.904144 -15.967984 -16.031888]
#  [-16.063936 -15.999968 -15.936064 ..., -15.872224 -15.936064 -15.999968]
#  [-16.031984 -15.968016 -15.904112 ..., -15.840272 -15.904112 -15.968016]]
# 6.3 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
# %%timeit -n 1 -r 1
fxy_v = xx**2 - 2*yy**2
print(fxy_v)
# Vectorized implementation
# Out:
# [[-16.       -16.031984 -16.063936 ..., -16.095856 -16.063936 -16.031984]
#  [-15.936032 -15.968016 -15.999968 ..., -16.031888 -15.999968 -15.968016]
#  [-15.872128 -15.904112 -15.936064 ..., -15.967984 -15.936064 -15.904112]
#  ...,
#  [-15.808288 -15.840272 -15.872224 ..., -15.904144 -15.872224 -15.840272]
#  [-15.872128 -15.904112 -15.936064 ..., -15.967984 -15.936064 -15.904112]
#  [-15.936032 -15.968016 -15.999968 ..., -16.031888 -15.999968 -15.968016]]
# 15.9 ms ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
print("Time [sec] (non-vectorized): {}".format(6.3))
print("Time [sec] (vectorized): {}".format(0.00159))
tmp = 6.3/0.00159
print("The vectorized code is %5.3f times faster than the non-vectorized code."% tmp)
# Print the time for each and the speed increase
# Out:
# Time [sec] (non-vectorized): 6.3
# Time [sec] (vectorized): 0.00159
# The vectorized code is 3962.264 times faster than the non-vectorized code.

# %%
# %config InlineBackend.figure_format = 'retina'

fxy = xx**2 - 2*yy**2

plt.imshow(fxy)
plt.xlabel("x from -4 to 4")
plt.ylabel("y from -4 to 4")
plt.show()

for i in range(2000):
    for j in range(2000):
        if fxy[i,j]<0:
            fxy[i,j] = 0
plt.imshow(fxy) 
plt.xlabel("Filtered x from -4 to 4")
plt.ylabel("Filtered y from -4 to 4")
plt.show()

# Plot the result

# %% [markdown]
# ## 9
# This exercise will walk through some basic numerical programming exercises.
# 1. Synthesize $n=10^4$ normally distributed data points with mean $\mu=2$ and a standard deviation of $\sigma=1$. Call these observations from a random variable $X$, and call the vector of observations that you generate, $\textbf{x}$.
# 2. Calculate the mean and standard deviation of $\textbf{x}$ to validate (1) and provide the result to a precision of four significant figures.
# 3. Plot a histogram of the data in $\textbf{x}$ with 30 bins
# 4. What is the 90th percentile of $\textbf{x}$? The 90th percentile is the value below which 90% of observations can be found.
# 5. What is the 99th percentile of $\textbf{x}$?
# 6. Now synthesize $n=10^4$ normally distributed data points with mean $\mu=0$ and a standard deviation of $\sigma=3$. Call these observations from a random variable $Y$, and call the vector of observations that you generate, $\textbf{y}$.
# 7. Plot the histogram of the data in $\textbf{y}$ on a (new) plot with the histogram of $\textbf{x}$, so that both histograms can be seen and compared.
# 8. Using the observations from $\textbf{x}$ and $\textbf{y}$, estimate $E[XY]$

# %% [markdown]
# **ANSWER**

# %%
import numpy as np
# %config InlineBackend.figure_format = 'retina'

# 1
mu, sigma = 2, 1 # mean and standard deviation
x = np.random.normal(mu, sigma, 10000)

# 2
mean = np.mean(x)
std = np.std(x, ddof=1)
print("The mean of x is %5.3f" %(mean))
print("The standard deviation of x is %5.3f"%std)

# 3
import matplotlib.pyplot as plt
count, bins, patches = plt.hist(x, 30)
plt.xlabel("Numerical value of data points")
plt.ylabel("Frequency")
plt.show()
# 4
pct90 = np.percentile(x, 90)
print("The 90th percentile of x is %5.3f" %pct90)
# 5
pct99 = np.percentile(x, 99)
print("The 99th percentile of x is %5.3f" %pct99)
# 6
mu, sigma = 0, 3 # mean and standard deviation
y = np.random.normal(mu, sigma, 10000)
# 7
count, bins, patches = plt.hist(y, 30,alpha = 0.5,label = "Data group 2")
count, bins, patches = plt.hist(x, 30,facecolor = "green", alpha = 0.5,label = "Data group 1")
plt.xlabel("Numerical value of data points")
plt.ylabel("Frequency")
plt.legend()
plt.show()
# 8

xy = x*y
exp_xy = np.mean(xy)
print("The expectation of XY is %5.3f." %exp_xy)
# Out:
# The mean of x is 1.986
# The standard deviation of x is 0.999
# The 90th percentile of x is 3.286
# The 99th percentile of x is 4.319
# The expectation of XY is -0.132.

# %% [markdown]
# ## 10
# Estimate the integral of the function $f(x)$ on the interval $0\leq x < 2.5$ assuming we only know the following points from $f$:
#
# *Table 1. Dataset containing n=5 observations*
#
# | $x_i$ | 0.0 | 0.5 | 1.0 | 1.5 | 2.0 |
# |-|-|-|-|-|-|
# | $y_i$ | 6 | 7 | 8 | 4 | 1 |

# %% [markdown]
# **ANSWER**
#
#
# For this question I used numpy.polyfit to perform least squares polynomial fit. The data points looks like they have a shape of parabola. Therefore I adopted degree of 2. The polinomial fit function is $f = -3.714x^2 + 4.829x + 5.943$. The reason I did not choose function with higher degree is that it could lead to overfitting, when the function is strictly closer to every data points but
#
# Therefore, the area under the function in the interval $[0,2.5)$ can be evaluated by $\int_{0}^{2.5}-3.714x^2 + 4.829x + 5.943$. Using integrating function in python, we get a result of 10.604.

# %%
import numpy as np
x = np.array([0.0, 0.5, 1.0, 1.5, 2.0])
y = np.array([6.0, 7.0, 8.0, 4.0, 1.0])
z = np.polyfit(x, y, 2)

# %%
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
xp = np.linspace(0, 2, 10)
p = np.poly1d(z)
print(p)
plt.plot(x, y, '.',label = "Data Points")
plt.plot(xp, p(xp), '-', label = "Fx")
plt.xlabel("Numerical value of x")
plt.ylabel("Numerical value of y")
plt.legend()
plt.show()
# Out:
#         2
# -3.714 x + 4.829 x + 5.943

# %%
from scipy.integrate import quad

def integrand(x):
    return -3.714*x**2 + 4.829*x + 5.943

ans, err = quad(integrand, 0, 2.5)
print("%5.3f" %ans)
# Out:
# 10.604

# %% [markdown]
# # Version Control via Git

# %% [markdown]
# ## 11
# Complete the [Atlassian Git tutorial](https://www.atlassian.com/git/tutorials/what-is-version-control), specifically the following sections. Try each concept that's presented. For this tutorial, instead of using BitBucket, use Github. Create a github account here if you don't already have one: https://github.com/
# 1. [What is version control](https://www.atlassian.com/git/tutorials/what-is-version-control)
# 2. [What is Git](https://www.atlassian.com/git/tutorials/what-is-git)
# 3. [Install Git](https://www.atlassian.com/git/tutorials/install-git)
# 4. [Setting up a repository](https://www.atlassian.com/git/tutorials/install-git)
# 5. [Saving changes](https://www.atlassian.com/git/tutorials/saving-changes)
# 6. [Inspecting a repository](https://www.atlassian.com/git/tutorials/inspecting-a-repository)
# 7. [Undoing changes](https://www.atlassian.com/git/tutorials/undoing-changes)
# 8. [Rewriting history](https://www.atlassian.com/git/tutorials/rewriting-history)
# 9. [Syncing](https://www.atlassian.com/git/tutorials/syncing)
# 10. [Making a pull request](https://www.atlassian.com/git/tutorials/making-a-pull-request)
# 11. [Using branches](https://www.atlassian.com/git/tutorials/using-branches)
# 12. [Comparing workflows](https://www.atlassian.com/git/tutorials/comparing-workflows)
#
# For your answer, affirm that you either completed the tutorial or have previous experience with all of the concepts above. Do this by typing your name below and selecting the situation that applies from the two options in brackets.

# %% [markdown]
# **ANSWER**
#
# I, Yujing Ke, affirm that I have completed the above tutorial.

# %% [markdown]
# ## 12
# Using Github to create a static HTML website:
# 1. Create a branch in your `machine-learning-course` repo called "gh-pages" and checkout that branch (this will provide an example of how to create a simple static website using [Github Pages](https://pages.github.com/))
# 2. Create a file called "index.html" with the contents "Hello World" and add, commit, and push it to that branch.
# 3. Submit the following: (a) a link to your github repository and (b) a link to your new "Hello World" website. The latter should be at the address https://[USERNAME].github.io/ECE590-assignment0 (where [USERNAME] is your github username).

# %% [markdown]
# **ANSWER**
#
# (a)https://github.com/y-ke/machine-learning-course
#
# (b)https://y-ke.github.io/machine-learning-course/

# %% [markdown]
# # Exploratory Data Analysis
# ## 13
# Here you'll bring together some of the individual skills that you demonstrated above and create a Jupyter notebook based blog post on data analysis.
#
# 1. Find a dataset that interests you and relates to a question or problem that you find intriguing
# 2. Using a Jupyter notebook, describe the dataset, the source of the data, and the reason the dataset was of interest.
# 3. Check the data and see if they need to be cleaned: are there missing values? Are there clearly erroneous values? Do two tables need to be merged together? Clean the data so it can be visualized.
# 3. Plot the data, demonstrating interesting features that you discover. Are there any relationships between variables that were surprising or patterns that emerged? Please exercise creativity and curiosity in your plots.
# 4. What insights are you able to take away from exploring the data? Is there a reason why analyzing the dataset you chose is particularly interesting or important? Summarize this as if your target audience was the readership of a major news organization - boil down your findings in a way that is accessible, but still accurate.
# 5. Create a public repository on your github account titled "machine-learning-course". In it, create a readme file that contains the heading "ECE590: Introductory Machine Learning for Data Science". Add, commit, and push that Jupyter notebook to the master branch. Provide the link to the that post here.

# %% [markdown]
# **ANSWER**
#
# - (1 & 2) The dataset that interests me and relates to a question that I find intriguing is the Titanic Machine learning data set from Kaggle https://www.kaggle.com/c/titanic/data. I am curious is there any age pattern in survival that I could detect. This data set includes the “features” like passengers’ gender and age.
#
# - (3) By looking at the data set, I can find that there are some entries with NaN value such as age or cabin. No clearly erroneous values spotted by a glance. This .csv file is the only given training data set therefore merging tables is not necessary. I replaced NaN age entries with value 100 after checking there is no actual passenger that was 100 years old.
#
# - (4) I ploted a histogram of the passengers' age. We can see that there are many NaN value in the raw data. Other than that, the majority of the passengers aged between 18-40. It is very surprusing to know that infants and little kids with age under 5 has higher survival rate than adults.
#
# - (5) The reason behind the surprising fact that kids under 5 has higher survival rate than adults could be complicated, but to make some reasonable guess, it could be at the time of evacuation, kids are more likely to be taken care of and their parents might even give up their own living to ensure their kids' safety.
#
# - (6) The link is https://github.com/y-ke/machine-learning-course.

# %%
import pandas as pd
mydata = pd.read_csv('./train.csv')
# mydata.head()

# %%
mydata.Age = mydata.Age.fillna(100)


count, bins, patches = plt.hist(mydata.Age, 20,alpha = 0.5)
survived = mydata.Survived.apply(lambda x: x == 1)
count, bins, patches = plt.hist(mydata[survived].Age, 20,facecolor = 'orange',alpha = 0.9,label = 'Survivor')
plt.xlabel("")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
# mydata
